# %% [markdown]
# <a href="https://colab.research.google.com/github/vashisthyatharth06/NeuralNet_WearableClassification/blob/master/NeuralNet_WearableClassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing modules
import tensorflow as tf 
from tensorflow import keras
import numpy as np 
import matplotlib.pyplot as plt

#Loading dataset
data = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = data.load_data()


class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

train_images = train_images/255.0
test_images = test_images/255.0

#Creating Neural Network
model = keras.Sequential([
	keras.layers.Flatten(input_shape=(28,28)),
	keras.layers.Dense(128, activation="relu"),
	keras.layers.Dense(10, activation="softmax")
	])

model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

#Training Model
model.fit(train_images, train_labels, epochs=8)

#Evaluating Performance of Model on dataset
test_loss, test_acc = model.evaluate(test_images, test_labels)

print('\nTest accuracy:', test_acc) #Best model after changing values of different parameters of model.
# Out:
# Epoch 1/8
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5002 - accuracy: 0.8233
# Epoch 2/8
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3750 - accuracy: 0.8644
# Epoch 3/8
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3353 - accuracy: 0.8777
# Epoch 4/8
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3121 - accuracy: 0.8855
# Epoch 5/8
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2952 - accuracy: 0.8903
# Epoch 6/8
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2810 - accuracy: 0.8959
# Epoch 7/8
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2679 - accuracy: 0.9000
# Epoch 8/8
# ...
# 313/313 [==============================] - 0s 1ms/step - loss: 0.3447 - accuracy: 0.8808
#
# Test accuracy: 0.8808000087738037

# %%
#Making Predictions with our model
predictions = model.predict(test_images)
plt.figure(figsize=(5,5))
for i in range(5):
    plt.grid(False)
    plt.imshow(test_images[i], cmap=plt.cm.binary)
    plt.xlabel("Actual: "+ class_names[test_labels[i]])
    plt.title("Predicted: "+class_names[np.argmax(predictions[i])])
    plt.show()

#End of Code
